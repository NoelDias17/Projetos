# %% [markdown]
# #### Lembrar:
# - Atualizar Lista dos Médicos
# - Renomear pasta destino

# %% [markdown]
# ### GSC - Convênios

# %%
import pyautogui
import pyperclip
import time
from datetime import datetime

dicionario_meses = {'01':'JANEIRO','02':'FEVEREIRO','03':'MARÇO','04':'ABRIL','05':'MAIO','06':'JUNHO',
                    '07':'JULHO','08':'AGOSTO','09':'SETEMBRO','10':'OUTUBRO','11':'NOVEMBRO','12':'DEZEMBRO'}

data = datetime.today().strftime('%Y-%m-%d')
mes_num = data[5:7]

mes_ant = int(mes_num) - 1
mes_ant = '0' + str(mes_ant)

medicos = ['Alexandra Rech Vieira', 'Ana Isis Gouveia Ramos', 'Ana Paula Bovaretto Tessari', 'Andressa de Deus Mateus', 
           'Beatriz Veloso Aiex', 'Bruno Porto Soares', 'Camila Paiva Henty de Farias ', 'Carolinne Cerqueira Alves', 
           'Cecilia Maria de Oliveira Aquino Sequeira', 'Cesar Augusto Hernandez', 'Eleonora Pati Quinhoes', 
           'Eneas Van Der Maas do Bem Filho', 'Flavia Ramos Pinto', 'Gerson Schorr', 'Giovana Schorr', 
           'Giovanna Abrantes Pimenta de Figueiredo', 'Giovanna Petrilli', 'Glaucia Monteiro da Costa Goncalves', 
           'Isabella de Azevedo Dossin', 'Janine Andressa Costa', 'Joana da Silva Petito', 'Juliana Crespo do Nascimento', 
           'Juliana de Souza Von Borell Rangel', 'Kim Scofield Emerick', 'Lara Francischetto Milleri', 
           'Lisa Franceschetto Milleri', 'Lucas Emmels Malaquias', 'Marcele Trindade dos Santos', 
           'Maria Lina de Souza Resende', 'Maria Vitoria Meller Milioli', 'Mariana Cristina Costa e Santos', 
           'Marilia Barbosa Cavalcante Silva', 'Marina Ramos Costa', 'Morgana Longo', 'Nicole Carolina Vieira Peruchi', 
           'Olivia Schorr', 'Otavio Barea Pattussi', 'Paula Cardoso Correa Filgueiras', 'Paula Zanella Caus', 
           'Paula Zanette Peruchi', "Renato Mont' Alvao Seixas de Siqueira", 'Rita Fernanda Cortez de Almeida', 
           'Simone Desjardins', 'Tulio Neutzling Zanchin', 'Vivian Nunes Alexandre Ivo de Figueiredo']

pyautogui.PAUSE = 0.5

pyautogui.alert('Favor deixar o ASA Maximizado de fundo!')
time.sleep(3)
pyautogui.click(x=53, y=72)
pyautogui.click(x=256, y=144)
pyautogui.click(x=319, y=383)
pyautogui.click(x=402, y=384)
time.sleep(1)
pyautogui.click(x=117, y=241)
pyautogui.click(x=603, y=644)
time.sleep(4)
pyautogui.click(x=655, y=47)
pyautogui.click(x=305, y=68)

pyautogui.PAUSE = 0.1

for click in range(25):
    pyautogui.click(x=290, y=488)
    
pyautogui.PAUSE = 0.5

pyautogui.click(x=452, y=296)
pyautogui.press('SPACE')

# Filtrar Médico
pyautogui.click(x=61, y=275)

for medico in medicos:
    pyautogui.click(x=364, y=282)
    
    pyautogui.PAUSE = 0.1
    
    for deletar in range(50):
        pyautogui.press('DEL')
    time.sleep(1)
    pyperclip.copy(medico)
    pyautogui.hotkey('ctrl','v')
#     pyautogui.write(medico)
    
    pyautogui.PAUSE = 0.5
    
    pyautogui.press('ENTER')
    pyautogui.hotkey('alt','v')

    #salvar relatório CAIXA A
    time.sleep(8)
    pyautogui.click(x=20, y=34)
    time.sleep(2)
    pyautogui.click(x=460, y=466)
    pyautogui.click(x=691, y=494)
    pyautogui.click(x=550, y=548)
    pyautogui.click(x=531, y=522)
    pyperclip.copy(r'S:\Relatorios medicos\{}\{}.pdf'.format(medico, 'relconv' + mes_ant + '22'))
#     pyperclip.copy(r'S:\Relatorios medicos\{}\{}.pdf'.format(medico, 'teste_automação' + mes_ant + '22'))
    pyautogui.hotkey('ctrl','v')
    pyautogui.press('enter')
    time.sleep(15)
    pyautogui.click(x=1331, y=6)
    time.sleep(2)

pyautogui.alert('Relatórios Médicos Salvos com Sucesso!')
# Out:
# KeyboardInterrupt

# %% [markdown]
# ### GSC - Particular

# %%
import pyautogui
import pyperclip
import time
from datetime import datetime

dicionario_meses = {'01':'JANEIRO','02':'FEVEREIRO','03':'MARÇO','04':'ABRIL','05':'MAIO','06':'JUNHO',
                    '07':'JULHO','08':'AGOSTO','09':'SETEMBRO','10':'OUTUBRO','11':'NOVEMBRO','12':'DEZEMBRO'}

data = datetime.today().strftime('%Y-%m-%d')
mes_num = data[5:7]

mes_ant = int(mes_num) - 1
mes_ant = '0' + str(mes_ant)

# 'Adriana Dinoa', 

medicos = ['Alexandra Rech Vieira', 'Ana Isis Gouveia Ramos', 'Ana Paula Bovaretto Tessari', 'Andressa de Deus Mateus', 'Beatriz Veloso Aiex', 'Bruno Porto Soares', 'Carolinne Cerqueira Alves', 'Cesar Augusto Hernandez', 'Eleonora Pati Quinhoes', 'Eneas Van Der Maas do Bem Filho', 'Gerson Schorr', 'Giovana Schorr', 'Giovanna Abrantes Pimenta de Figueiredo', 'Giovanna Petrilli', 'Isabella de Azevedo Dossin', 'Janine Andressa Costa', 'Joana da Silva Petito', 'Juliana Crespo do Nascimento', 'Juliana de Souza Von Borell Rangel', 'Kim Scofield Emerick', 'Lara Francischetto Milleri', 'Lisa Franceschetto Milleri', 'Lucas Emmels Malaquias', 'Marcele Trindade dos Santos', 'Maria Lina de Souza Resende', 'Marilia Barbosa Cavalcante Silva', 'Nicole Carolina Vieira Peruchi', 'Olivia Schorr', 'Otavio Barea Pattussi', 'Paula Cardoso Correa Filgueiras', 'Paula Zanella Caus', 'Paula Zanette Peruchi', 'Rita Fernanda Cortez de Almeida', 'Simone Desjardins', 'Tulio Neutzling Zanchin', 'Vivian Nunes Alexandre Ivo de Figueiredo']

pyautogui.PAUSE = 0.5

pyautogui.alert('Favor deixar o ASA Maximizado de fundo!')
time.sleep(3)
pyautogui.click(x=53, y=72)
pyautogui.click(x=256, y=144)
pyautogui.click(x=319, y=383)
pyautogui.click(x=402, y=384)
time.sleep(1)
pyautogui.click(x=117, y=241)
pyautogui.click(x=603, y=644)
time.sleep(4)
pyautogui.click(x=655, y=47)
pyautogui.click(x=229, y=85)
# pyautogui.click(x=305, y=68)

pyautogui.PAUSE = 0.1

for click in range(25):
    pyautogui.click(x=290, y=488)
    
pyautogui.PAUSE = 0.5

pyautogui.click(x=452, y=296)
pyautogui.press('SPACE')

# Filtrar Médico
pyautogui.click(x=61, y=275)

for medico in medicos:
    pyautogui.click(x=364, y=282)
    
    pyautogui.PAUSE = 0.1
    
    for deletar in range(50):
        pyautogui.press('DEL')
    time.sleep(1)
    pyperclip.copy(medico)
    pyautogui.hotkey('ctrl','v')
#     pyautogui.write(medico)
    
    pyautogui.PAUSE = 0.5
    
    pyautogui.press('ENTER')
    pyautogui.hotkey('alt','v')

    #salvar relatório CAIXA A
    time.sleep(8)
    pyautogui.click(x=20, y=34)
    time.sleep(2)
    pyautogui.click(x=460, y=466)
    pyautogui.click(x=691, y=494)
    pyautogui.click(x=550, y=548)
    pyautogui.click(x=531, y=522)
    pyperclip.copy(r'S:\Relatorios medicos\{}\{}.pdf'.format(medico, 'relpart' + mes_ant + '22'))
#     pyperclip.copy(r'S:\Relatorios medicos\{}\{}.pdf'.format(medico, 'teste_automação_part' + mes_ant + '22'))
    pyautogui.hotkey('ctrl','v')
    pyautogui.press('enter')
    time.sleep(15)
    pyautogui.click(x=1331, y=6)
    time.sleep(2)

pyautogui.alert('Relatórios Médicos Salvos com Sucesso!')
# Out:
# 'OK'

# %% [markdown]
# ### CMS - Convênios
#
# #### Não esquecer de mudar: unidade, empresa e convenios

# %%
import pyautogui
import pyperclip
import time
from datetime import datetime

dicionario_meses = {'01':'JANEIRO','02':'FEVEREIRO','03':'MARÇO','04':'ABRIL','05':'MAIO','06':'JUNHO',
                    '07':'JULHO','08':'AGOSTO','09':'SETEMBRO','10':'OUTUBRO','11':'NOVEMBRO','12':'DEZEMBRO'}

data = datetime.today().strftime('%Y-%m-%d')
mes_num = data[5:7]

mes_ant = int(mes_num) - 1
mes_ant = '0' + str(mes_ant)

# medicos = ['Alexandra Rech Vieira', 'Ana Isis Gouveia Ramos', 'Ana Paula Bovaretto Tessari', 'Andressa de Deus Mateus', 'Beatriz Veloso Aiex', 'Bruno Porto Soares', 'Carolinne Cerqueira Alves', 'Cesar Augusto Hernandez', 'Eleonora Pati Quinhoes', 'Eneas Van Der Maas do Bem Filho', 'Gerson Schorr', 'Giovana Schorr', 'Giovanna Abrantes Pimenta de Figueiredo', 'Giovanna Petrilli', 'Isabella de Azevedo Dossin', 'Janine Andressa Costa', 'Joana da Silva Petito', 'Juliana Crespo do Nascimento', 'Juliana de Souza Von Borell Rangel', 'Kim Scofield Emerick', 'Lara Francischetto Milleri', 'Lisa Franceschetto Milleri', 'Lucas Emmels Malaquias', 'Marcele Trindade dos Santos', 'Maria Lina de Souza Resende', 'Marilia Barbosa Cavalcante Silva', 'Nicole Carolina Vieira Peruchi', 'Olivia Schorr', 'Otavio Barea Pattussi', 'Paula Cardoso Correa Filgueiras', 'Paula Zanella Caus', 'Paula Zanette Peruchi', 'Rita Fernanda Cortez de Almeida', 'Simone Desjardins', 'Tulio Neutzling Zanchin', 'Vivian Nunes Alexandre Ivo de Figueiredo']
medicos = ['Eneas Van Der Maas do Bem Filho', 'Gerson Schorr', 'Giovana Schorr', 'Giovanna Abrantes Pimenta de Figueiredo', 'Giovanna Petrilli', 'Isabella de Azevedo Dossin', 'Janine Andressa Costa', 'Joana da Silva Petito', 'Juliana Crespo do Nascimento', 'Juliana de Souza Von Borell Rangel', 'Kim Scofield Emerick', 'Lara Francischetto Milleri', 'Lisa Franceschetto Milleri', 'Lucas Emmels Malaquias', 'Marcele Trindade dos Santos', 'Maria Lina de Souza Resende', 'Marilia Barbosa Cavalcante Silva', 'Nicole Carolina Vieira Peruchi', 'Olivia Schorr', 'Otavio Barea Pattussi', 'Paula Cardoso Correa Filgueiras', 'Paula Zanella Caus', 'Paula Zanette Peruchi', 'Rita Fernanda Cortez de Almeida', 'Simone Desjardins', 'Tulio Neutzling Zanchin', 'Vivian Nunes Alexandre Ivo de Figueiredo']


pyautogui.PAUSE = 0.5

pyautogui.alert('Favor deixar o ASA Maximizado de fundo!')
time.sleep(3)
# pyautogui.click(x=53, y=72)
# pyautogui.click(x=256, y=144)
# pyautogui.click(x=319, y=383)
# pyautogui.click(x=402, y=384)
# time.sleep(1)
# pyautogui.click(x=117, y=241)
# pyautogui.click(x=603, y=644)
# time.sleep(4)
# pyautogui.click(x=655, y=47)
# pyautogui.click(x=305, y=68)

# pyautogui.PAUSE = 0.1

# for click in range(25):
#     pyautogui.click(x=290, y=488)
    
# pyautogui.PAUSE = 0.5

# pyautogui.click(x=452, y=296)
# pyautogui.press('SPACE')

# # Filtrar Médico
# pyautogui.click(x=61, y=275)

for medico in medicos:
    pyautogui.click(x=364, y=282)
    
    pyautogui.PAUSE = 0.1
    
    for deletar in range(50):
        pyautogui.press('DEL')
    time.sleep(1)
    pyperclip.copy(medico)
    pyautogui.hotkey('ctrl','v')
#     pyautogui.write(medico)
    
    pyautogui.PAUSE = 0.5
    
    pyautogui.press('ENTER')
    pyautogui.hotkey('alt','v')

    #salvar relatório CAIXA A
    time.sleep(8)
    pyautogui.click(x=20, y=34)
    time.sleep(2)
    pyautogui.click(x=460, y=466)
    pyautogui.click(x=691, y=494)
    pyautogui.click(x=550, y=548)
    pyautogui.click(x=531, y=522)
    pyperclip.copy(r'S:\Relatorios medicos\CENTRO MÉDICO\{}\{}.pdf'.format(medico, 'relconv' + mes_ant + '22'))
    
#     pyperclip.copy(r'S:\Relatorios medicos\{}\{}.pdf'.format(medico, 'teste_automação' + mes_ant + '22'))
    pyautogui.hotkey('ctrl','v')
    pyautogui.press('enter')
    time.sleep(15)
    pyautogui.click(x=1331, y=6)
    time.sleep(2)

pyautogui.alert('Relatórios Médicos Salvos com Sucesso!')
# Out:
# 'OK'

# %% [markdown]
# ### CMS - Particular

# %%
import pyautogui
import pyperclip
import time
from datetime import datetime

dicionario_meses = {'01':'JANEIRO','02':'FEVEREIRO','03':'MARÇO','04':'ABRIL','05':'MAIO','06':'JUNHO',
                    '07':'JULHO','08':'AGOSTO','09':'SETEMBRO','10':'OUTUBRO','11':'NOVEMBRO','12':'DEZEMBRO'}

data = datetime.today().strftime('%Y-%m-%d')
mes_num = data[5:7]

mes_ant = int(mes_num) - 1
mes_ant = '0' + str(mes_ant)

medicos = ['Alexandra Rech Vieira', 'Ana Isis Gouveia Ramos', 'Ana Paula Bovaretto Tessari', 'Andressa de Deus Mateus', 'Beatriz Veloso Aiex', 'Bruno Porto Soares', 'Carolinne Cerqueira Alves', 'Cesar Augusto Hernandez', 'Eleonora Pati Quinhoes', 'Eneas Van Der Maas do Bem Filho', 'Gerson Schorr', 'Giovana Schorr', 'Giovanna Abrantes Pimenta de Figueiredo', 'Giovanna Petrilli', 'Isabella de Azevedo Dossin', 'Janine Andressa Costa', 'Joana da Silva Petito', 'Juliana Crespo do Nascimento', 'Juliana de Souza Von Borell Rangel', 'Kim Scofield Emerick', 'Lara Francischetto Milleri', 'Lisa Franceschetto Milleri', 'Lucas Emmels Malaquias', 'Marcele Trindade dos Santos', 'Maria Lina de Souza Resende', 'Marilia Barbosa Cavalcante Silva', 'Nicole Carolina Vieira Peruchi', 'Olivia Schorr', 'Otavio Barea Pattussi', 'Paula Cardoso Correa Filgueiras', 'Paula Zanella Caus', 'Paula Zanette Peruchi', 'Rita Fernanda Cortez de Almeida', 'Simone Desjardins', 'Tulio Neutzling Zanchin', 'Vivian Nunes Alexandre Ivo de Figueiredo']

pyautogui.PAUSE = 0.5

pyautogui.alert('Favor deixar o ASA Maximizado de fundo!')
time.sleep(3)
# pyautogui.click(x=53, y=72)
# pyautogui.click(x=256, y=144)
# pyautogui.click(x=319, y=383)
# pyautogui.click(x=402, y=384)
# time.sleep(1)
# pyautogui.click(x=117, y=241)
# pyautogui.click(x=603, y=644)
# time.sleep(4)
# pyautogui.click(x=655, y=47)
# pyautogui.click(x=305, y=68)

# pyautogui.PAUSE = 0.1

# for click in range(25):
#     pyautogui.click(x=290, y=488)
    
# pyautogui.PAUSE = 0.5

# pyautogui.click(x=452, y=296)
# pyautogui.press('SPACE')

# # Filtrar Médico
# pyautogui.click(x=61, y=275)

for medico in medicos:
    pyautogui.click(x=364, y=282)
    
    pyautogui.PAUSE = 0.1
    
    for deletar in range(50):
        pyautogui.press('DEL')
    time.sleep(1)
    pyperclip.copy(medico)
    pyautogui.hotkey('ctrl','v')
#     pyautogui.write(medico)
    
    pyautogui.PAUSE = 0.5
    
    pyautogui.press('ENTER')
    pyautogui.hotkey('alt','v')

    #salvar relatório CAIXA A
    time.sleep(8)
    pyautogui.click(x=20, y=34)
    time.sleep(2)
    pyautogui.click(x=460, y=466)
    pyautogui.click(x=691, y=494)
    pyautogui.click(x=550, y=548)
    pyautogui.click(x=531, y=522)
    pyperclip.copy(r'S:\Relatorios medicos\CENTRO MÉDICO\{}\{}.pdf'.format(medico, 'relpart' + mes_ant + '22'))
    
#     pyperclip.copy(r'S:\Relatorios medicos\{}\{}.pdf'.format(medico, 'teste_automação' + mes_ant + '22'))
    pyautogui.hotkey('ctrl','v')
    pyautogui.press('enter')
    time.sleep(15)
    pyautogui.click(x=1331, y=6)
    time.sleep(2)

pyautogui.alert('Relatórios Médicos Salvos com Sucesso!')
# Out:
# 'OK'
